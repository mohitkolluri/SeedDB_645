# %%
! pip install -r requirements.txt
from pruning_optimization import pruning_optimization
! pip install pandas
! pip install matplotlib
import seedb
import matplotlib
# Out:
# Requirement already satisfied: psycopg2==2.9.3 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (2.9.3)
# WARNING: You are using pip version 21.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/mohitkolluri/.pyenv/versions/3.8.10/bin/python3.8 -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.20.0 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from pandas) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 21.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/mohitkolluri/.pyenv/versions/3.8.10/bin/python3.8 -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (3.5.0)
# Requirement already satisfied: setuptools-scm>=4 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from matplotlib) (6.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from matplotlib) (4.28.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from matplotlib) (1.21.4)
# Requirement already satisfied: packaging>=20.0 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from matplotlib) (21.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: six>=1.5 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib) (1.2.2)
# Requirement already satisfied: setuptools in /Users/mohitkolluri/.pyenv/versions/3.8.10/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib) (56.0.0)
# WARNING: You are using pip version 21.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/mohitkolluri/.pyenv/versions/3.8.10/bin/python3.8 -m pip install --upgrade pip' command.

# %% [markdown]
# # Get interesting visualization

# %%
fam_set = seedb.generate_fams()
print(f"Length of fam_set = {len(fam_set)}")

top_k_interesting_visualizations = pruning_optimization(fam_set)
print(top_k_interesting_visualizations)
# Out:
# Length of fam_set = 250
# OrderedDict([(('min', 'native_country', 'fnlwgt'), 304.9704507918456), (('min', 'native_country', 'hours_per_week'), 302.61012719968403), (('avg', 'native_country', 'fnlwgt'), 298.85298199109064), (('max', 'native_country', 'fnlwgt'), 297.99270325442865), (('min', 'native_country', 'age'), 297.9419853460284)])

# %%
SQL_QUERY = """
SELECT q1.aggregate, q1.val, q2.val from (
(SELECT {} as aggregate, {} as val from census_income.adult where marital_status in 
('Married-civ-spouse', 'Widowed', 'Married-spouse-absent', 'Married-AF-spouse', 'Separated') group by {}) q1 
left outer join 
(SELECT {} as aggregate, {} as val from census_income.adult where marital_status in 
('Divorced','Never-married') group by {}) q2
on q1.aggregate = q2.aggregate);
"""
import database_connection
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def generate_query(f,a,m):
    return SQL_QUERY.format(a, f'{f}({m})', a, a, f'{f}({m})', a)
                            
def get_results(f,a,m):
    sql_query = generate_query(f,a,m)
    return database_connection.execute_query(sql_query)

def get_dataframe(f,a,m,result):
    res = pd.DataFrame(columns=['{}'.format(a), 'Marital_Status', '{}({})'.format(f.upper(),m)])
    for a, val_1, val_2 in result:
        res.loc[len(res)] = [a,'True', int(val_1)]
        res.loc[len(res)] = [a,'False', int(val_2)]
        
    res.fillna("0", inplace=True)
    return res

def generate_graph(f,a,m,result):
    #print(result)
    x = np.arange(1,(len(result))/2+1)
    width = 0.5
    plt.figure(figsize=(30,10))
    plt.bar(x-0.4, result[res['Marital_Status'] == 'True']['{}({})'.format(f.upper(),m)].to_list(), align='edge', width=0.4, color='green')
    plt.bar(x, result[res['Marital_Status'] == 'False']['{}({})'.format(f.upper(),m)].to_list(), align='edge', width=0.4, color='orange')
    plt.xticks(x, result[res['Marital_Status'] == 'False'][a].to_list())
    plt.xlabel(a.upper(),fontsize=20)
    plt.ylabel('{}({})'.format(f.upper(),m),fontsize=20)
    plt.legend(["Married","Unmarried"])
    plt.rc('xtick', labelsize=20) 
    plt.rc('ytick', labelsize=20) 
    plt.rc('legend', fontsize=20)
    plt.xticks(rotation = 90)
    plt.show()

for k in top_k_interesting_visualizations.keys():
    f,a,m = k
    res = get_results(f,a,m)
    res = get_dataframe(f,a,m, res)
    generate_graph(f,a,m, res)
# Out:
#    native_country Marital_Status  MIN(fnlwgt)
# 0           Italy           True        37913
# 1           Italy          False        89182
# 2         Ecuador           True       126569
# 3         Ecuador          False       153805
# 4        Columbia           True       100662
# ..            ...            ...          ...
# 77    Philippines          False        20057
# 78        Jamaica           True        78356
# 79        Jamaica          False        34532
# 80       Thailand           True        22201
# 81       Thailand          False        67053
#
# [82 rows x 3 columns]
#    native_country Marital_Status  MIN(hours_per_week)
# 0           Italy           True                    6
# 1           Italy          False                    8
# 2         Ecuador           True                   22
# 3         Ecuador          False                   25
# 4        Columbia           True                    5
# ..            ...            ...                  ...
# 77    Philippines          False                   15
# 78        Jamaica           True                   16
# 79        Jamaica          False                   10
# 80       Thailand           True                   35
# 81       Thailand          False                   10
#
# [82 rows x 3 columns]
#    native_country Marital_Status  AVG(fnlwgt)
# 0           Italy           True       181181
# 1           Italy          False       183482
# 2         Ecuador           True       187275
# 3         Ecuador          False       183669
# 4        Columbia           True       236516
# ..            ...            ...          ...
# 77    Philippines          False       158965
# 78        Jamaica           True       196099
# 79        Jamaica          False       225656
# 80       Thailand           True       166804
# 81       Thailand          False       205868
#
# [82 rows x 3 columns]
#    native_country Marital_Status  MAX(fnlwgt)
# 0           Italy           True       573583
# 1           Italy          False       353263
# 2         Ecuador           True       313945
# 3         Ecuador          False       224870
# 4        Columbia           True      1161363
# ..            ...            ...          ...
# 77    Philippines          False       554206
# 78        Jamaica           True       401623
# 79        Jamaica          False       387116
# 80       Thailand           True       257295
# 81       Thailand          False       361341
#
# [82 rows x 3 columns]
#    native_country Marital_Status  MIN(age)
# 0           Italy           True        28
# 1           Italy          False        19
# 2         Ecuador           True        24
# 3         Ecuador          False        21
# 4        Columbia           True        25
# ..            ...            ...       ...
# 77    Philippines          False        17
# 78        Jamaica           True        18
# 79        Jamaica          False        19
# 80       Thailand           True        24
# 81       Thailand          False        19
#
# [82 rows x 3 columns]
